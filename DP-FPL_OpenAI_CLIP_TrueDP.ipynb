# %%
# Full TRUE-DP Implementation (matching the ICLR paper)

# Per-batch gradient clipping (Cth = 10)

# Gaussian mechanism (LDP + GDP) added properly

# ε–δ privacy calculation using advanced composition

# Low-rank factorization + residual

# Federated prompt learning (10 clients)

# OpenAI CLIP ViT-B/32 frozen

# Oxford Flowers-102 dataset

# Personalization vs Generalization accuracy

# CPU-only implementation
